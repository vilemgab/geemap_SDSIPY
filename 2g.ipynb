# %% [markdown]
# <a href="https://colab.research.google.com/github/vilemgab/geemap_SDSIPY/blob/main/2g.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee
ee.Authenticate()

# %%
from oauth2client.client import GoogleCredentials

# zadejte vlastni oznaceni projektu

ee.Initialize(project='')

# %%
import geemap
m = geemap.Map()

# %%
# zde vlozte jeden vlastni polygon
geometry = ee.Geometry.Polygon([
    [
[-00.804035482162, 00.33678113198104],
[-00.804035482162, 00.79490729901023],
[-00.672687825911998, 00.79490729901023],
[-00.672687825911998, 00.33678113198104]
    ]
    ])

# roi ci jiny nazev vasi promenne pro definovani oblasti
roi = geometry

# %%
snippet = """



# Zde vlozte vlastni GEE code

"""

geemap.js_snippet_to_py(snippet, add_new_cell=True, import_ee=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# zavolejme vysledek
m

# %%
# export html
import os
download_dir = '/content'
html_file = os.path.join(download_dir, "my_map.html")
m.to_html(filename=html_file, title="My Map", width="100%", height="880px")
